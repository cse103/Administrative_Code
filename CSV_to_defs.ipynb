# %%
import pandas as pd
import argparse
import datetime

# %%
df = pd.read_csv('set_assignments.csv')
df
# Out:
#     Set Name                                      PG File Path
# 0      Week0            Reorganized/EventSpace/event_tree_1.pg
# 1      Week0            Reorganized/EventSpace/event_tree_2.pg
# 2      Week0            Reorganized/EventSpace/event_tree_3.pg
# 3      Week0            Reorganized/EventSpace/event_tree_4.pg
# 4      Week0            Reorganized/EventSpace/event_tree_5.pg
# 5      Week0            Reorganized/EventSpace/event_tree_6.pg
# 6      Week0                 Reorganized/Orientation/prob01.pg
# 7      Week0                 Reorganized/Orientation/prob02.pg
# 8      Week0                 Reorganized/Orientation/prob03.pg
# 9      Week0                 Reorganized/Orientation/prob04.pg
# 10     Week0                 Reorganized/Orientation/prob05.pg
# 11     Week0                 Reorganized/Orientation/prob06.pg
# 12     Week0                 Reorganized/Orientation/prob07.pg
# 13     Week0                 Reorganized/Orientation/prob08.pg
# 14     Week0                 Reorganized/Orientation/prob09.pg
# 15     Week0                 Reorganized/Orientation/prob10.pg
# 16     Week0                 Reorganized/Orientation/prob11.pg
# 17     Week0                 Reorganized/Orientation/prob12.pg
# 18     Week0                 Reorganized/Orientation/prob13.pg
# 19     Week0                 Reorganized/Orientation/prob14.pg
# 20     Week0                 Reorganized/Orientation/prob15.pg
# 21     Week1                   Reorganized/Sets/BasicSets_1.pg
# 22     Week1                   Reorganized/Sets/BasicSets_2.pg
# 23     Week1                   Reorganized/Sets/BasicSets_3.pg
# 24     Week1                            Reorganized/Sets/q2.pg
# 25     Week1                    Reorganized/Sets/BasicSets1.pg
# 26     Week1                     Reorganized/Sets/ClassSize.pg
# 27     Week2                  Reorganized/Combinatorics/p10.pg
# 28     Week2       Reorganized/Combinatorics/sw10_2_14_PGML.pg
# 29     Week2                  Reorganized/Combinatorics/p11.pg
# ..       ...                                               ...
# 119    Week6       Reorganized/ExponentialPoisson/ur_pb_9_2.pg
# 120    Week6      Reorganized/ExponentialPoisson/poisson_rs.pg
# 121    Week6      Reorganized/Covariance/ContingencyTables1.pg
# 122    Week6      Reorganized/Covariance/ContingencyTables2.pg
# 123    Week6      Reorganized/Covariance/ContingencyTables5.pg
# 124    Week6      Reorganized/Covariance/ContingencyTables7.pg
# 125    Week6      Reorganized/Covariance/ContingencyTables8.pg
# 126    Week6                       Reorganized/Covariance/2.pg
# 127    Week6                       Reorganized/Covariance/1.pg
# 128    Week7     Reorganized/CentralLimitTheorem/ur_pb_12_4.pg
# 129    Week7     Reorganized/CentralLimitTheorem/ur_pb_11_7.pg
# 130    Week7     Reorganized/CentralLimitTheorem/ur_pb_12_3.pg
# 131    Week7     Reorganized/CentralLimitTheorem/ur_pb_11_1.pg
# 132    Week7     Reorganized/CentralLimitTheorem/ur_pb_11_3.pg
# 133    Week7       Reorganized/CentralLimitTheorem/clt_demo.pg
# 134    Week7         Reorganized/HypothesisTesting/seatbelt.pg
# 135    Week7            Reorganized/HypothesisTesting/error.pg
# 136    Week7          Reorganized/HypothesisTesting/psychic.pg
# 137    Week7    Reorganized/HypothesisTesting/paired_t_test.pg
# 138    Week7           Reorganized/HypothesisTesting/pooled.pg
# 139    Week7           Reorganized/HypothesisTesting/gust63.pg
# 140    Week7           Reorganized/HypothesisTesting/gust75.pg
# 141    Week7       Reorganized/HypothesisTesting/ur_stt_4_1.pg
# 142    Week7  Reorganized/HypothesisTesting/MultipleTesting.pg
# 143    Week7             Reorganized/HypothesisTesting/drug.pg
# 144    Week8             Reorganized/RandomizedAlgs/probs94.pg
# 145    Week8        Reorganized/RandomizedAlgs/RandAlgs_2_1.pg
# 146    Week8        Reorganized/RandomizedAlgs/RandAlgs_2_2.pg
# 147    Week8           Reorganized/RandomizedAlgs/Hashing_1.pg
# 148    Week8           Reorganized/RandomizedAlgs/Hashing_2.pg
#
# [149 rows x 2 columns]

# %%
sets = sorted(set(df['Set Name']))
start_date = datetime.datetime(2014, 10, 1, 12)
week = datetime.timedelta(days=7)
for set_id in sets:
    with open("set{0}.def".format(set_id), 'w') as def_file:
        end_date = start_date + week
        tz_open = 'PST' if start_date.month >=11 and start_date.day>=3 else 'PDT'
        tz_close = 'PST' if end_date.month >=11 and end_date.day>=3 else 'PDT'
        def_file.write("openDate          = {0} {1}\n".format(
                    start_date.strftime('%m/%d/%Y at %I:%M%p'), tz_open))
        def_file.write("dueDate           = {0} {1}\n".format(
                    end_date.strftime('%m/%d/%Y at %I:%M%p'), tz_close))
        def_file.write("answerDate        = {0} {1}\n".format(
            end_date.strftime('%m/%d/%Y at %I:%M%p'), tz_close))
        
        def_file.write("paperHeaderFile   = defaultHeader\n")
        def_file.write("screenHeaderFile  = defaultHeader\n")
        def_file.write("problemList       =\n")

        start_date = end_date
        set_problems = df[df['Set Name']==set_id]['PG File Path']
        for problem in set_problems:
            def_file.write("{0}\n".format(problem))
# Out:
# Week0
# Week1
# Week2
# Week3
# Week4
# Week5
# Week6
# Week7
# Week8
# XCombinatoricsProbability
